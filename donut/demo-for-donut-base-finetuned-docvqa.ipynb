# %%
cd ozbdocrecog/
# Out:
# /home/juliaju_o/ozon_bank/ozbdocrecog

# %%
import pandas as pd
tools = pd.read_csv('tools.csv', sep=';', on_bad_lines='skip').drop('Unnamed: 7', axis=1)
tools
# Out:
#                                              Category  \
# 0                        Large Language Models (LLMs)
# 1   These are general-purpose language models that...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                     Vision-Language Models (VLLMs)
# 12  These models can understand and process both v...
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                         Multimodal Neural Networks
# 20  These models combine multiple modalities (text...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                OCR Models for Document Recognition
# 39  These OCR engines are suitable for extracting ...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
#
#                        Name  \
# 0                     Bloom
# 1                    Falcon
# 2                   Flan-T5
# 3         GPT-Neo and GPT-J
# 4                  Kosmos-1
# 5                     LLaMA
# 6                   Mistral
# 7                    Claude
# 8                    Gemini
# 9                     GPT-4
# 10                     Grok
# 11                    Donut
# 12                    Molmo
# 13                     NVLM
# 14               Pix2Struct
# 15                 Qwen2-VL
# 16              XLM-Roberta
# 17               LayoutLMv3
# 18                    LLaVA
# 19                    ALIGN
# 20                   BEiT-3
# 21                   BLIP-2
# 22                     CLIP
# 23                     CoCa
# 24                DocFormer
# 25                 Flamingo
# 26                  FormNet
# 27                 LayoutLM
# 28                      MM1
# 29                      OFA
# 30               OmniFusion
# 31                     PaLI
# 32                 PandaGPT
# 33                   SimVLM
# 34                StrucTexT
# 35                    TAPAS
# 36                     TILT
# 37                     UDOP
# 38                Adobe OCR
# 39          Amazon Textract
# 40                    CLaMM
# 41                    DocTR
# 42                  EasyOCR
# 43  Google Cloud Vision OCR
# 44                Keras-OCR
# 45                      M4C
# 46      Microsoft Azure OCR
# 47                PaddleOCR
# 48                  SelfDoc
# 49            Tesseract OCR
# 50                    TrOCR
# 51   ICDAR 2024 Proceedings
#
#                                           Description  \
# 0                  A multilingual LLM, many languages
# 1   LLM for summarization, question answering, and...
# 2   Instruction-tuned model based on T5, capable o...
# 3   Open-source versions inspired by GPT-3, useful...
# 4   A rudimentary reimplementation of the KOSMOS-1...
# 5                           Good for custom NLP tasks
# 6       Suitable for document processing applications
# 7      Optimized for safe and interpretable responses
# 8                     Audio, images, videos, and text
# 9                  Generative Pre-trained Transformer
# 10  A variety of tasks, including generating and u...
# 11  Designed for structured document understanding...
# 12            A family of open vision-language models
# 13                Open Frontier-Class Multimodal LLMs
# 14  Vision-language model, focused on document str...
# 15  SoTA understanding of images of various resolu...
# 16  Multilingual VLLM with fine-tuning potential f...
# 17  Specialized in document layout understanding, ...
# 18  Модель, которая объединяет языковые и визуальн...
# 19  Can be used for image-text similarity and for ...
# 20  Image as a Foreign Language: BEiT Pretraining ...
# 21  A multimodal model tailored to image-to-text a...
# 22  A model trained on image-text pairs that can b...
# 23  Модель может фокусироваться на различных аспек...
# 24  Применяется для понимания сложных документов и...
# 25  Multimodal model for tasks that require simult...
# 26  Performance on natural language and document u...
# 27  Обрабатывает текстовую информацию, визуальную ...
# 28  Способна решать задачи, связанные с изображени...
# 29  A multimodal framework useful for various docu...
# 30  Первая в России мультимодальная модель, способ...
# 31  Генерация текстов на основе изображений и визу...
# 32  Combines visual and language capabilities, ena...
# 33  Используется для генерации описаний изображени...
# 34  Structured text understanding on Visually Rich...
# 35         For answering questions about tabular data
# 36  Arctic-TILT is a Snowflake-grown LLM that leve...
# 37  For document AI tasks like document image clas...
# 38  OCR for PDFs, making it ideal for document wor...
# 39  A cloud-based OCR service that goes beyond sim...
# 40  Provides specialized OCR for historical and ha...
# 41  Robust two-stage OCR predictors that efficient...
# 42  Built on PyTorch, it’s good for both handwritt...
# 43  Part of its cloud-based image recognition serv...
# 44  An OCR pipeline using Keras and TensorFlow, su...
# 45  Iterative Answer Prediction with Pointer-Augme...
# 46  Part of its cloud services, providing accurate...
# 47  Advanced OCR engine with multilingual support ...
# 48  Использует подход самосупервизируемого обучени...
# 49  A widely used, reliable OCR tool that supports...
# 50  Transformer-based OCR model that can handle ha...
# 51  The 18th International Conference on Document ...
#
#                             Company      Payment  \
# 0                        BigScience  Open-source
# 1   Technology Innovation Institute  Open-source
# 2                            Google  Open-source
# 3                        EleutherAI  Open-source
# 4                               NaN  Open-source
# 5                              Meta  Open-source
# 6                        Mistral AI  Open-source
# 7                         Anthropic          NaN
# 8                   Google DeepMind          NaN
# 9                            OpenAI          NaN
# 10                              xAI          NaN
# 11                            NAVER  Open-source
# 12                              NaN  Open-source
# 13                              NaN  Open-source
# 14                              NaN  Open-source
# 15           Allen Institute for AI  Open-source
# 16                              NaN  Open-source
# 17                        Microsoft          NaN
# 18                        Microsoft          NaN
# 19                              NaN  Open-source
# 20                              NaN  Open-source
# 21                       Salesforce  Open-source
# 22                           OpenAI  Open-source
# 23                              NaN  Open-source
# 24                              NaN       Статья
# 25                              NaN       Статья
# 26                              NaN       Статья
# 27                        Microsoft  Open-source
# 28                              NaN       Статья
# 29                              NaN  Open-source
# 30                             AIRI  Open-source
# 31                              NaN  Open-source
# 32                   Tencent AI Lab  Open-source
# 33                              NaN  Open-source
# 34                              NaN       Статья
# 35                              NaN  Open-source
# 36                       Snowflake           NaN
# 37                              NaN          NaN
# 38                            Adobe          NaN
# 39                           Amazon          NaN
# 40                              NaN          NaN
# 41                              NaN  Open-source
# 42                              NaN  Open-source
# 43                           Google          NaN
# 44                              NaN  Open-source
# 45                              NaN  Open-source
# 46                        Microsoft          NaN
# 47             PaddlePaddle (Baidu)  Open-source
# 48                              NaN       Статья
# 49                              NaN  Open-source
# 50                        Microsoft  Open-source
# 51                              NaN          NaN
#
#                                                  Link  \
# 0             https://huggingface.co/bigscience/bloom
# 1       https://huggingface.co/tiiuae/falcon-mamba-7b
# 2          https://huggingface.co/google/flan-t5-base
# 3              https://sapling.ai/llm/gpt-j-vs-gptneo
# 4   https://github.com/bjoernpl/KOSMOS_reimplement...
# 5                https://github.com/meta-llama/llama3
# 6                            https://docs.mistral.ai/
# 7                  https://docs.anthropic.com/en/home
# 8               https://ai.google.dev/gemini-api/docs
# 9       https://platform.openai.com/docs/introduction
# 10                                   https://x.ai/api
# 11  https://huggingface.co/naver-clova-ix/donut-ba...
# 12     https://huggingface.co/allenai/Molmo-7B-D-0924
# 13                    https://nvlm-project.github.io/
# 14      https://github.com/google-research/pix2struct
# 15                 https://github.com/QwenLM/Qwen2-VL
# 16  https://huggingface.co/laion/CLIP-ViT-B-32-xlm...
# 17  https://huggingface.co/docs/transformers/model...
# 18                        https://llava-vl.github.io/
# 19  https://huggingface.co/docs/transformers/model...
# 20  https://github.com/microsoft/unilm/tree/master...
# 21  https://huggingface.co/docs/transformers/model...
# 22                     https://github.com/openai/CLIP
# 23         https://github.com/lucidrains/CoCa-pytorch
# 24                https://github.com/shabie/docformer
# 25     https://github.com/mlfoundations/open_flamingo
# 26                                                NaN
# 27  https://huggingface.co/docs/transformers/model...
# 28                                                NaN
# 29                     https://github.com/OFA-Sys/OFA
# 30       https://github.com/AIRI-Institute/OmniFusion
# 31                   https://github.com/kyegomez/PALI
# 32                       https://panda-gpt.github.io/
# 33            https://github.com/YulongBonjour/SimVLM
# 34                                                NaN
# 35  https://huggingface.co/docs/transformers/model...
# 36  https://www.snowflake.com/en/blog/arctic-tilt-...
# 37  https://huggingface.co/docs/transformers/model...
# 38  https://experienceleague.adobe.com/en/docs/doc...
# 39                   https://aws.amazon.com/textract/
# 40                        https://clamm.irht.cnrs.fr/
# 41                    https://github.com/mindee/doctr
# 42                https://github.com/JaidedAI/EasyOCR
# 43           https://cloud.google.com/vision/docs/ocr
# 44        https://keras-ocr.readthedocs.io/en/latest/
# 45                  https://mmf.sh/docs/projects/m4c/
# 46  https://learn.microsoft.com/ru-ru/azure/ai-ser...
# 47          https://github.com/PaddlePaddle/PaddleOCR
# 48                                                NaN
# 49         https://github.com/tesseract-ocr/tesseract
# 50  https://huggingface.co/docs/transformers/model...
# 51                https://icdar2024.net/procceedings/
#
#                                arxiv
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                               NaN
# 11                               NaN
# 12                               NaN
# 13                               NaN
# 14                               NaN
# 15                               NaN
# 16                               NaN
# 17                               NaN
# 18                               NaN
# 19                               NaN
# 20                               NaN
# 21                               NaN
# 22                               NaN
# 23                               NaN
# 24  https://arxiv.org/abs/2106.11539
# 25  https://arxiv.org/abs/2204.14198
# 26  https://arxiv.org/abs/2203.08411
# 27                               NaN
# 28  https://arxiv.org/abs/2403.09611
# 29                               NaN
# 30                               NaN
# 31  https://arxiv.org/abs/2209.06794
# 32                               NaN
# 33  https://arxiv.org/abs/2108.10904
# 34  https://arxiv.org/abs/2108.02923
# 35                               NaN
# 36                               NaN
# 37                               NaN
# 38                               NaN
# 39                               NaN
# 40                               NaN
# 41                               NaN
# 42                               NaN
# 43                               NaN
# 44                               NaN
# 45                               NaN
# 46                               NaN
# 47                               NaN
# 48  https://arxiv.org/abs/2106.03331
# 49                               NaN
# 50                               NaN
# 51                               NaN

# %%
conda env list
# Out:
# # conda environments:
# #
# base                     /home/juliaju_o/miniconda3
# donut_official        *  /home/juliaju_o/miniconda3/envs/donut_official
# jupyter_notebook         /home/juliaju_o/miniconda3/envs/jupyter_notebook
# prokka1146               /home/juliaju_o/miniconda3/envs/prokka1146
# quast                    /home/juliaju_o/miniconda3/envs/quast
# singularity              /home/juliaju_o/miniconda3/envs/singularity
# spades                   /home/juliaju_o/miniconda3/envs/spades
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# Donut: Document Understanding Transformer
# https://github.com/clovaai/donut

# https://github.com/clovaai/donut/issues/206
# !pip install donut-python
# !pip install transformers==4.25.1
# !pip install pytorch-lightning==1.6.4
# !pip install timm==0.5.4
# !pip install gradio
# !pip install donut-python
# Out:
# Requirement already satisfied: donut-python in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (1.0.9)
# Requirement already satisfied: pytorch-lightning>=1.6.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (1.6.4)
# Requirement already satisfied: zss in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (1.2.0)
# Requirement already satisfied: transformers>=4.11.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (4.25.1)
# Requirement already satisfied: sentencepiece in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (0.2.0)
# Requirement already satisfied: datasets[vision] in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (2.13.2)
# Requirement already satisfied: sconf>=0.2.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (0.2.5)
# Requirement already satisfied: timm in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (0.5.4)
# Requirement already satisfied: nltk in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (3.8.1)
# Requirement already satisfied: protobuf<=3.20.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (3.20.1)
# Requirement already satisfied: packaging>=17.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (24.0)
# Requirement already satisfied: numpy>=1.17.2 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (1.21.6)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2.11.2)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (0.3.2)
# Requirement already satisfied: PyYAML>=5.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (6.0.1)
# Requirement already satisfied: torchmetrics>=0.4.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (0.11.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (4.7.1)
# Requirement already satisfied: torch>=1.8.* in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (1.13.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2023.1.0)
# Requirement already satisfied: tqdm>=4.57.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (4.66.6)
# Requirement already satisfied: munch in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from sconf>=0.2.3->donut-python) (4.0.0)
# Requirement already satisfied: ruamel.yaml in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from sconf>=0.2.3->donut-python) (0.18.6)
# Requirement already satisfied: importlib-metadata in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (6.7.0)
# Requirement already satisfied: filelock in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (3.12.2)
# Requirement already satisfied: requests in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (2.31.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (0.16.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (2024.4.16)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (0.13.3)
# Requirement already satisfied: multiprocess in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (0.70.14)
# Requirement already satisfied: xxhash in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (3.5.0)
# Requirement already satisfied: pandas in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (1.3.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (12.0.1)
# Requirement already satisfied: aiohttp in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (3.8.6)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (0.3.6)
# Requirement already satisfied: Pillow>=6.2.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (9.5.0)
# Requirement already satisfied: joblib in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from nltk->donut-python) (1.3.2)
# Requirement already satisfied: click in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from nltk->donut-python) (8.1.7)
# Requirement already satisfied: torchvision in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from timm->donut-python) (0.14.1)
# Requirement already satisfied: six in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from zss->donut-python) (1.16.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (6.0.5)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (24.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (4.0.3)
# Requirement already satisfied: asynctest==0.13.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (0.13.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (3.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->transformers>=4.11.3->donut-python) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->transformers>=4.11.3->donut-python) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->transformers>=4.11.3->donut-python) (2.0.7)
# Requirement already satisfied: setuptools>=41.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (65.6.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.1.0)
# Requirement already satisfied: grpcio>=1.24.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.62.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.35.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (11.10.3.66)
# Requirement already satisfied: zipp>=0.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from importlib-metadata->transformers>=4.11.3->donut-python) (3.15.0)
# Requirement already satisfied: pytz>=2017.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pandas->datasets[vision]->donut-python) (2024.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pandas->datasets[vision]->donut-python) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from ruamel.yaml->sconf>=0.2.3->donut-python) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (3.2.2)
# Requirement already satisfied: transformers==4.25.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (4.25.1)
# Requirement already satisfied: requests in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers==4.25.1) (2.31.0)
# Requirement already satisfied: importlib-metadata in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers==4.25.1) (6.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers==4.25.1) (24.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers==4.25.1) (2024.4.16)
# Requirement already satisfied: filelock in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers==4.25.1) (3.12.2)
# Requirement already satisfied: tqdm>=4.27 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers==4.25.1) (4.66.6)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers==4.25.1) (0.13.3)
# Requirement already satisfied: numpy>=1.17 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers==4.25.1) (1.21.6)
# Requirement already satisfied: pyyaml>=5.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers==4.25.1) (6.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers==4.25.1) (0.16.4)
# Requirement already satisfied: fsspec in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.25.1) (2023.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.25.1) (4.7.1)
# Requirement already satisfied: zipp>=0.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from importlib-metadata->transformers==4.25.1) (3.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->transformers==4.25.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->transformers==4.25.1) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->transformers==4.25.1) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->transformers==4.25.1) (2.0.7)
# Requirement already satisfied: pytorch-lightning==1.6.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (1.6.4)
# Requirement already satisfied: torch>=1.8.* in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (1.13.1)
# Requirement already satisfied: tqdm>=4.57.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (4.66.6)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (2023.1.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (2.11.2)
# Requirement already satisfied: protobuf<=3.20.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (4.7.1)
# Requirement already satisfied: PyYAML>=5.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (6.0.1)
# Requirement already satisfied: packaging>=17.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (24.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (0.11.4)
# Requirement already satisfied: numpy>=1.17.2 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (1.21.6)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning==1.6.4) (0.3.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (3.8.6)
# Requirement already satisfied: requests in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2.35.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2.1.0)
# Requirement already satisfied: grpcio>=1.24.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (1.62.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (3.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (65.6.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.4) (0.4.6)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning==1.6.4) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning==1.6.4) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning==1.6.4) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning==1.6.4) (8.5.0.96)
# Requirement already satisfied: asynctest==0.13.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (6.0.5)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (3.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (24.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (4.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (6.7.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.4) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.6.4) (3.2.2)
# Requirement already satisfied: timm==0.5.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (0.5.4)
# Requirement already satisfied: torch>=1.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from timm==0.5.4) (1.13.1)
# Requirement already satisfied: torchvision in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from timm==0.5.4) (0.14.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.4->timm==0.5.4) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.4->timm==0.5.4) (8.5.0.96)
# Requirement already satisfied: typing-extensions in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.4->timm==0.5.4) (4.7.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.4->timm==0.5.4) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.4->timm==0.5.4) (11.7.99)
# Requirement already satisfied: setuptools in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.4->timm==0.5.4) (65.6.3)
# Requirement already satisfied: wheel in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.4->timm==0.5.4) (0.38.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torchvision->timm==0.5.4) (9.5.0)
# Requirement already satisfied: requests in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torchvision->timm==0.5.4) (2.31.0)
# Requirement already satisfied: numpy in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torchvision->timm==0.5.4) (1.21.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->torchvision->timm==0.5.4) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->torchvision->timm==0.5.4) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->torchvision->timm==0.5.4) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->torchvision->timm==0.5.4) (2022.12.7)
# Requirement already satisfied: gradio in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (3.34.0)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: gradio-client>=0.2.6 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (0.2.6)
# Requirement already satisfied: matplotlib in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (3.5.3)
# Requirement already satisfied: pyyaml in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: httpx in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (0.24.1)
# Requirement already satisfied: jinja2 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (3.1.4)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (0.22.0)
# Requirement already satisfied: orjson in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (3.9.7)
# Requirement already satisfied: pandas in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (1.3.5)
# Requirement already satisfied: altair>=4.2.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (5.0.1)
# Requirement already satisfied: pillow in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (9.5.0)
# Requirement already satisfied: pygments>=2.12.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (2.17.2)
# Requirement already satisfied: pydantic in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (2.5.3)
# Requirement already satisfied: pydub in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: ffmpy in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (0.3.2)
# Requirement already satisfied: websockets>=10.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (11.0.3)
# Requirement already satisfied: fastapi in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (0.103.2)
# Requirement already satisfied: markupsafe in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (2.1.5)
# Requirement already satisfied: python-multipart in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (0.0.8)
# Requirement already satisfied: typing-extensions in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (4.7.1)
# Requirement already satisfied: aiohttp in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (3.8.6)
# Requirement already satisfied: numpy in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (1.21.6)
# Requirement already satisfied: aiofiles in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (22.1.0)
# Requirement already satisfied: semantic-version in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (0.16.4)
# Requirement already satisfied: requests in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (2.31.0)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: importlib-metadata in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from altair>=4.2.0->gradio) (6.7.0)
# Requirement already satisfied: jsonschema>=3.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from altair>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from altair>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: fsspec in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio-client>=0.2.6->gradio) (2023.1.0)
# Requirement already satisfied: packaging in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from gradio-client>=0.2.6->gradio) (24.0)
# Requirement already satisfied: filelock in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from huggingface-hub>=0.14.0->gradio) (3.12.2)
# Requirement already satisfied: tqdm>=4.42.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from huggingface-hub>=0.14.0->gradio) (4.66.6)
# Requirement already satisfied: mdurl~=0.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pandas->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pandas->gradio) (2024.2)
# Requirement already satisfied: click>=7.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from uvicorn>=0.14.0->gradio) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->gradio) (3.4.0)
# Requirement already satisfied: asynctest==0.13.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->gradio) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->gradio) (1.9.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->gradio) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->gradio) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->gradio) (4.0.3)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from fastapi->gradio) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pydantic->gradio) (2.14.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pydantic->gradio) (0.5.0)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from httpx->gradio) (0.17.3)
# Requirement already satisfied: idna in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from httpx->gradio) (3.10)
# Requirement already satisfied: certifi in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from httpx->gradio) (2022.12.7)
# Requirement already satisfied: sniffio in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from httpx->gradio) (1.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from matplotlib->gradio) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from matplotlib->gradio) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from matplotlib->gradio) (3.1.4)
# Requirement already satisfied: cycler>=0.10 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->gradio) (2.0.7)
# Requirement already satisfied: exceptiongroup in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.2.2)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (5.12.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Requirement already satisfied: uc-micro-py in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.3)
# Requirement already satisfied: six>=1.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->gradio) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from importlib-metadata->altair>=4.2.0->gradio) (3.15.0)
# Requirement already satisfied: donut-python in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (1.0.9)
# Requirement already satisfied: zss in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (1.2.0)
# Requirement already satisfied: pytorch-lightning>=1.6.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (1.6.4)
# Requirement already satisfied: datasets[vision] in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (2.13.2)
# Requirement already satisfied: nltk in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (3.8.1)
# Requirement already satisfied: transformers>=4.11.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (4.25.1)
# Requirement already satisfied: sconf>=0.2.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (0.2.5)
# Requirement already satisfied: timm in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (0.5.4)
# Requirement already satisfied: sentencepiece in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from donut-python) (0.2.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2.11.2)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (0.3.2)
# Requirement already satisfied: packaging>=17.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (24.0)
# Requirement already satisfied: PyYAML>=5.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (6.0.1)
# Requirement already satisfied: torchmetrics>=0.4.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (0.11.4)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (2023.1.0)
# Requirement already satisfied: protobuf<=3.20.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (3.20.1)
# Requirement already satisfied: torch>=1.8.* in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (1.13.1)
# Requirement already satisfied: numpy>=1.17.2 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (1.21.6)
# Requirement already satisfied: tqdm>=4.57.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pytorch-lightning>=1.6.4->donut-python) (4.7.1)
# Requirement already satisfied: ruamel.yaml in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from sconf>=0.2.3->donut-python) (0.18.6)
# Requirement already satisfied: munch in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from sconf>=0.2.3->donut-python) (4.0.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (2024.4.16)
# Requirement already satisfied: filelock in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (3.12.2)
# Requirement already satisfied: requests in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (0.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (0.16.4)
# Requirement already satisfied: importlib-metadata in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from transformers>=4.11.3->donut-python) (6.7.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (12.0.1)
# Requirement already satisfied: multiprocess in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (0.70.14)
# Requirement already satisfied: xxhash in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (3.5.0)
# Requirement already satisfied: pandas in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (1.3.5)
# Requirement already satisfied: aiohttp in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (3.8.6)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (0.3.6)
# Requirement already satisfied: Pillow>=6.2.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from datasets[vision]->donut-python) (9.5.0)
# Requirement already satisfied: joblib in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from nltk->donut-python) (1.3.2)
# Requirement already satisfied: click in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from nltk->donut-python) (8.1.7)
# Requirement already satisfied: torchvision in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from timm->donut-python) (0.14.1)
# Requirement already satisfied: six in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from zss->donut-python) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (24.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (0.13.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (3.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (6.0.5)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (4.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from aiohttp->datasets[vision]->donut-python) (1.9.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->transformers>=4.11.3->donut-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->transformers>=4.11.3->donut-python) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests->transformers>=4.11.3->donut-python) (2022.12.7)
# Requirement already satisfied: absl-py>=0.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.1.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (65.6.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (3.4.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.38.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.6.1)
# Requirement already satisfied: grpcio>=1.24.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (1.62.3)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from torch>=1.8.*->pytorch-lightning>=1.6.4->donut-python) (11.7.99)
# Requirement already satisfied: zipp>=0.5 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from importlib-metadata->transformers>=4.11.3->donut-python) (3.15.0)
# Requirement already satisfied: pytz>=2017.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pandas->datasets[vision]->donut-python) (2024.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pandas->datasets[vision]->donut-python) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from ruamel.yaml->sconf>=0.2.3->donut-python) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/juliaju_o/miniconda3/envs/donut_official/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.4->donut-python) (3.2.2)

# %%
import argparse
import gradio as gr
import torch
from PIL import Image

from donut import DonutModel

# %%
def demo_process_vqa(input_img, question):
    global pretrained_model, task_prompt, task_name
    input_img = Image.fromarray(input_img)
    user_prompt = task_prompt.replace("{user_input}", question)
    output = pretrained_model.inference(input_img, prompt=user_prompt)["predictions"][0]
    return output


def demo_process(input_img):
    global pretrained_model, task_prompt, task_name
    input_img = Image.fromarray(input_img)
    output = pretrained_model.inference(image=input_img, prompt=task_prompt)["predictions"][0]
    return output

# %%
torch.cuda.is_available()
# Out:
# True

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--task", type=str, default="docvqa")
parser.add_argument("--pretrained_path", type=str, default="naver-clova-ix/donut-base-finetuned-docvqa")
args, left_argv = parser.parse_known_args()

task_name = args.task
if "docvqa" == task_name:
    task_prompt = "<s_docvqa><s_question>{user_input}</s_question><s_answer>"
else:  # rvlcdip, cord, ...
    task_prompt = f"<s_{task_name}>"

pretrained_model = DonutModel.from_pretrained(args.pretrained_path, ignore_mismatched_sizes=True)
print(torch.cuda.is_available())

if torch.cuda.is_available():
    pretrained_model.half()
    device = torch.device("cuda")
    pretrained_model.to(device)
else:
    pretrained_model.encoder.to(torch.bfloat16)

pretrained_model.eval()

demo = gr.Interface(
    fn=demo_process_vqa if task_name == "docvqa" else demo_process,
    inputs=["image", "text"] if task_name == "docvqa" else "image",
    outputs="json",
    title=f"Donut 🍩 demonstration for `{task_name}` task",
)
demo.launch()
# Out:
# Some weights of the model checkpoint at naver-clova-ix/donut-base-finetuned-docvqa were not used when initializing DonutModel: ['encoder.model.norm.weight', 'encoder.model.norm.bias']
# - This IS expected if you are initializing DonutModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DonutModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# True
# IMPORTANT: You are using gradio version 3.34.0, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
